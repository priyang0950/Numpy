# %%
#Changing the Shape of an Array 
import numpy as np
a = np.array([[1,2],[3,4]]) 
print ("array a is :", a) 
print ("reshape array a is:",np.reshape(a,4))
# Out:
# array a is : [[1 2]
#  [3 4]]
# reshape array a is: [1 2 3 4]
